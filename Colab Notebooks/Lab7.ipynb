# %% [markdown]
# # Merge Sort in Python

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2

    left = arr[:mid]
    right = arr[mid:]

    left = merge_sort(left)
    right = merge_sort(right)

    return merge(left, right)

def merge(left, right):
    result = []
    left_idx = right_idx = 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            result.append(left[left_idx])
            left_idx += 1
        else:
            result.append(right[right_idx])
            right_idx += 1

    result.extend(left[left_idx:])
    result.extend(right[right_idx:])

    return result

if __name__ == "__main__":
    arr = [1,2,3,45,10,7,37,34,1,5,8,3,5,44,11,22,33,23,9]
    sorted_arr = merge_sort(arr)
    print(sorted_arr)
# Out:
# [1, 1, 2, 3, 3, 5, 5, 7, 8, 9, 10, 11, 22, 23, 33, 34, 37, 44, 45]

# %% [markdown]
# # Quick Sort in Python

# %% [markdown]
# # GCD in Python

# %%
def gcd(a, b):
    while b!= 0:
        a, b = b, a%b
    return a

print(gcd(9, 5))
# Out:
# 1

# %%
from collections import deque
st = deque()

st.append("A")
st.append("R")
st.append("G")
st.append("H")
st.append("A")

for _ in range(len(st)):
    print(st.pop())
# Out:
# A
# H
# G
# R
# A

# %%
from collections import Counter
str = "HelloHello welcome to CSE Python"
counter = Counter(str)
print(counter)
# Out:
# Counter({'l': 5, 'o': 5, 'e': 4, ' ': 4, 'H': 2, 't': 2, 'w': 1, 'c': 1, 'm': 1, 'C': 1, 'S': 1, 'E': 1, 'P': 1, 'y': 1, 'h': 1, 'n': 1})

# %%
from collections import namedtuple
Person = namedtuple('Person', ['name', 'age', 'location', 'profession'])
a = Person('Argha', 20, 'Kolkata', 'Student')
print(a.name)
print(a.age)
print(a[2])
# Out:
# Argha
# 20
# Kolkata

# %%
from collections import OrderedDict
o = OrderedDict({1:1, 2:2, 3:3, 4:4})
print("Before deleting items: ", o)
del o[3]
print("After deleting item: ", o)
# Out:
# Before deleting items:  OrderedDict([(1, 1), (2, 2), (3, 3), (4, 4)])
# After deleting item:  OrderedDict([(1, 1), (2, 2), (4, 4)])
